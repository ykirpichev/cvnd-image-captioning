# %%
import argparse
import os
from PIL import Image

def resize_image(image, size):
    """Resize an image to the given size."""
    return image.resize(size, Image.ANTIALIAS)

def resize_images(image_dir, output_dir, size):
    """Resize the images in 'image_dir' and save into 'output_dir'."""
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    images = os.listdir(image_dir)
    num_images = len(images)
    for i, image in enumerate(images):
        with open(os.path.join(image_dir, image), 'r+b') as f:
            with Image.open(f) as img:
                img = resize_image(img, size)
                img.save(os.path.join(output_dir, image), img.format)
        if i % 100 == 0:
            print ("[%d/%d] Resized the images and saved into '%s'."
                   %(i, num_images, output_dir))

def main(image_dir, output_dir, image_size):
    resize_images(image_dir, output_dir, image_size)

# %%
train = '../cocoapi/images/train2014/'
val  = '../cocoapi/images/val2014/'

resize_dir = '../cocoapi/resized_images/'

resize_train = os.path.join(resize_dir, 'train2014')
resize_val  = os.path.join(resize_dir, 'val2014')

image_size = [256, 256]

# %%
main(train, resize_train, image_size)
# Out:
# [0/82783] Resized the images and saved into '../cocoapi/resized_images/train2014'.
# [100/82783] Resized the images and saved into '../cocoapi/resized_images/train2014'.
# [200/82783] Resized the images and saved into '../cocoapi/resized_images/train2014'.
# [300/82783] Resized the images and saved into '../cocoapi/resized_images/train2014'.
# [400/82783] Resized the images and saved into '../cocoapi/resized_images/train2014'.
# [500/82783] Resized the images and saved into '../cocoapi/resized_images/train2014'.
# [600/82783] Resized the images and saved into '../cocoapi/resized_images/train2014'.
# [700/82783] Resized the images and saved into '../cocoapi/resized_images/train2014'.
# [800/82783] Resized the images and saved into '../cocoapi/resized_images/train2014'.
# [900/82783] Resized the images and saved into '../cocoapi/resized_images/train2014'.
# [1000/82783] Resized the images and saved into '../cocoapi/resized_images/train2014'.
# ...

# %%
main(val, resize_val, image_size)
# Out:
# [0/40504] Resized the images and saved into '../cocoapi/resized_images/val2014'.
# [100/40504] Resized the images and saved into '../cocoapi/resized_images/val2014'.
# [200/40504] Resized the images and saved into '../cocoapi/resized_images/val2014'.
# [300/40504] Resized the images and saved into '../cocoapi/resized_images/val2014'.
# [400/40504] Resized the images and saved into '../cocoapi/resized_images/val2014'.
# [500/40504] Resized the images and saved into '../cocoapi/resized_images/val2014'.
# [600/40504] Resized the images and saved into '../cocoapi/resized_images/val2014'.
# [700/40504] Resized the images and saved into '../cocoapi/resized_images/val2014'.
# [800/40504] Resized the images and saved into '../cocoapi/resized_images/val2014'.
# [900/40504] Resized the images and saved into '../cocoapi/resized_images/val2014'.
# [1000/40504] Resized the images and saved into '../cocoapi/resized_images/val2014'.
# ...
